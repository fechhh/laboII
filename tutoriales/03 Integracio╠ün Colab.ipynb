# %%
# !pip install -q kaggle

# %% [markdown]
# Crear en su drive una carpeta UA_MDM_LDI_II y dentro de esa una carpeta tutoriales donde deben colocar este archivo.
#
# Generar token acuerdo a esta guía: https://www.kaggle.com/discussions/general/74235.
# Luego subir a la carpeta UA_MDM_LDI_II del drive

# %%
from google.colab import files,drive

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls /content/gdrive/MyDrive/UA_MDM_LDI_II/
# Out:
# input/  kaggle.json  tutoriales/

# %%
#Con este comando se puede subir un archivo manualmente
#files.upload()

# %%
 ! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp /content/gdrive/MyDrive/UA_MDM_LDI_II/kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ref                                                           title                                            size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------------------  ----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# patricklford/global-ev-sales-2010-2024                        Global EV Sales: 2010-2024                       83KB  2024-07-19 13:40:22           1875         27  1.0
# marius2303/nissan-all-models-price-prediction-dataset         Nissan All Models Price Prediction Dataset      811KB  2024-07-27 11:50:10            912         24  1.0
# waqi786/global-air-quality-dataset                            Global Air Quality Dataset 🌍🌫️                  258KB  2024-07-28 10:35:09           1268         29  1.0
# ...

# %%
# !kaggle competitions download -c 'petfinder-adoption-prediction'
# Out:
# ...
# 100% 1.93G/1.94G [00:10<00:00, 249MB/s]
# 100% 1.94G/1.94G [00:10<00:00, 201MB/s]

# %%
! mkdir /content/gdrive/MyDrive/UA_MDM_LDI_II/input
! mkdir /content/gdrive/MyDrive/UA_MDM_LDI_II/input/petfinder-adoption-prediction
! mkdir /content/gdrive/MyDrive/UA_MDM_LDI_II/work
! mkdir /content/gdrive/MyDrive/UA_MDM_LDI_II/work/modelos
! mkdir /content/gdrive/MyDrive/UA_MDM_LDI_II/work/optuna_artifacts
! mkdir /content/gdrive/MyDrive/UA_MDM_LDI_II/work/optuna_temp_artifacts
# Out:
# mkdir: cannot create directory ‘/content/gdrive/MyDrive/UA_MDM_LDI_II/input’: File exists
# mkdir: cannot create directory ‘/content/gdrive/MyDrive/UA_MDM_LDI_II/input/petfinder-adoption-prediction’: File exists
# mkdir: cannot create directory ‘/content/gdrive/MyDrive/UA_MDM_LDI_II/work’: File exists
# mkdir: cannot create directory ‘/content/gdrive/MyDrive/UA_MDM_LDI_II/work/modelos’: File exists
# mkdir: cannot create directory ‘/content/gdrive/MyDrive/UA_MDM_LDI_II/work/optuna_artifacts’: File exists
# mkdir: cannot create directory ‘/content/gdrive/MyDrive/UA_MDM_LDI_II/work/optuna_temp_artifacts’: File exists

# %%
! unzip petfinder-adoption-prediction.zip -d /content/gdrive/MyDrive/UA_MDM_LDI_II/input/petfinder-adoption-prediction/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/gdrive/MyDrive/UA_MDM_LDI_II/input/petfinder-adoption-prediction/train_metadata/702bee848-5.json
#   inflating: /content/gdrive/MyDrive/UA_MDM_LDI_II/input/petfinder-adoption-prediction/train_metadata/703105908-1.json
#   inflating: /content/gdrive/MyDrive/UA_MDM_LDI_II/input/petfinder-adoption-prediction/train_metadata/703105908-2.json
#   inflating: /content/gdrive/MyDrive/UA_MDM_LDI_II/input/petfinder-adoption-prediction/train_metadata/703105908-3.json
#   inflating: /content/gdrive/MyDrive/UA_MDM_LDI_II/input/petfinder-adoption-prediction/train_metadata/703105908-4.json
#   inflating: /content/gdrive/MyDrive/UA_MDM_LDI_II/input/petfinder-adoption-prediction/train_metadata/703105908-5.json
#   inflating: /content/gdrive/MyDrive/UA_MDM_LDI_II/input/petfinder-adoption-prediction/train_metadata/703374c74-1.json
# ...

# %%
En los notebooks que corran tienen que montar su drive:

from google.colab import files,drive
drive.mount('/content/gdrive')
 
Tienen que referenciar correctamente el BASE_DIR
BASE_DIR = '/content/gdrive/MyDrive/UA_MDM_LDI_II/'

Tienen que referenciar correctamente la ubicacion de la carpeta utils....
from gdrive.MyDrive.UA_MDM_LDI_II.tutoriales.utils import plot_confusion_matrix


Referencia a base optuna
#Defino el estudio a optimizar
study = optuna.create_study(direction='maximize', #buscamos maximizar la metrica
                            storage="sqlite:////content/gdrive/MyDrive/UA_MDM_LDI_II/work/db.sqlite3",  # Specify the storage URL here.
                            study_name="04 - LGB Multiclass", #nombre del experimento
                            load_if_exists=True) #continuar si ya existe



Para mostrar el dashboard de optuna en colab
import optuna
import threading
from google.colab import output
from optuna_dashboard import run_server


# Start Optuna Dashboard
port = 8082
thread = threading.Thread(target=run_server, args=("sqlite:////content/gdrive/MyDrive/UA_MDM_LDI_II/work/db.sqlite3",), kwargs={"port": port})
thread.start()
output.serve_kernel_port_as_window(port, path='/dashboard/')


Tendran que instalar las librerias necesarias...
# !pip install optuna
